# %%
import pandas as pd

# %% [markdown]
# In Pandas have two data stuctures
#
# 1.Series - 1D array
#
# 2.Data Frames - 2D array

# %% [markdown]
# #Series

# %%
data =pd.Series([1,2,3,4,5])
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data =pd.Series([1,2,3,4,5],index= ['a','b','c','d','e'])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# Dataframe

# %%
data =pd.DataFrame([1,2,3,4,5])
data
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
data =pd.DataFrame([1,2,3,4,5],index= ['a','b','c','d','e'])
data
# Out:
#    0
# a  1
# b  2
# c  3
# d  4
# e  5

# %%
lst = [[12,34,54,6,7],[23,45,67,8,9]]
df = pd.DataFrame(lst)
df
# Out:
#     0   1   2  3  4
# 0  12  34  54  6  7
# 1  23  45  67  8  9

# %% [markdown]
# Dictionary

# %%
dict = {'name':['Tom','Jerry','Mickey','Donald'],'age':[23,34,45,56]}
df = pd.DataFrame(dict)
df
# Out:
#      name  age
# 0     Tom   23
# 1   Jerry   34
# 2  Mickey   45
# 3  Donald   56

# %% [markdown]
# Add two dictonaries

# %%
dict1 = {'Tom':[24,324,43,54],'Mickey':[23,34,45,56]}
df1= pd.DataFrame(dict1)
dict2 = {'Jerry':[23,435,56,67],'Donald':[23,34,45,56]}
df2 = pd.DataFrame(dict2)

# %%
df1
# Out:
#    Tom  Mickey
# 0   24      23
# 1  324      34
# 2   43      45
# 3   54      56

# %%
df2
# Out:
#    Jerry  Donald
# 0     23      23
# 1    435      34
# 2     56      45
# 3     67      56

# %%
pd.concat([df1,df2]) #default axis = 0
# Out:
#      Tom  Mickey  Jerry  Donald
# 0   24.0    23.0    NaN     NaN
# 1  324.0    34.0    NaN     NaN
# 2   43.0    45.0    NaN     NaN
# 3   54.0    56.0    NaN     NaN
# 0    NaN     NaN   23.0    23.0
# 1    NaN     NaN  435.0    34.0
# 2    NaN     NaN   56.0    45.0
# 3    NaN     NaN   67.0    56.0

# %%
df = pd.concat([df1,df2],axis=1)
df
# Out:
#    Tom  Mickey  Jerry  Donald
# 0   24      23     23      23
# 1  324      34    435      34
# 2   43      45     56      45
# 3   54      56     67      56

# %% [markdown]
# Import csv file

# %%
data = pd.read_csv('weather.csv')

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Pressure9am  \
# 0             30.0         SW         NW           6.0  ...       1019.7
# ...

# %% [markdown]
# open another location csv file

# %%
data2 = pd.read_csv(r'D:\Projects for GitHub\publish knowing\Woring with Python libraries\weather.csv')
# if we want to open another folder we need to give the full path and add r before the path

# %%
data2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Pressure9am  \
# 0             30.0         SW         NW           6.0  ...       1019.7
# ...

# %% [markdown]
# find rows and columns

# %%
data2.shape
# Out:
# (366, 23)

# %% [markdown]
# remove unnecessary column

# %%
del data2['WindGustDir']

# %%
data2
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        8.0     24.3       0.0          3.4       6.3           30.0
# 1       14.0     26.9       3.6          4.4       9.7           39.0
# 2       13.7     23.4       3.6          5.8       3.3           85.0
# 3       13.3     15.5      39.8          7.2       9.1           54.0
# 4        7.6     16.1       2.8          5.6      10.6           50.0
# ..       ...      ...       ...          ...       ...            ...
# 361      9.0     30.7       0.0          7.6      12.1           76.0
# 362      7.1     28.4       0.0         11.6      12.7           48.0
# 363     12.5     19.9       0.0          8.4       5.3           43.0
# 364     12.5     26.9       0.0          5.0       7.1           46.0
# 365     12.3     30.2       0.0          6.0      12.6           78.0
#
#     WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  ...  Pressure9am  \
# ...

# %% [markdown]
# another way to remove comuns

# %%
data = data2.drop(columns=['WindDir9am','WindDir3pm'])

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0        8.0     24.3       0.0          3.4       6.3           30.0
# 1       14.0     26.9       3.6          4.4       9.7           39.0
# 2       13.7     23.4       3.6          5.8       3.3           85.0
# 3       13.3     15.5      39.8          7.2       9.1           54.0
# 4        7.6     16.1       2.8          5.6      10.6           50.0
# ..       ...      ...       ...          ...       ...            ...
# 361      9.0     30.7       0.0          7.6      12.1           76.0
# 362      7.1     28.4       0.0         11.6      12.7           48.0
# 363     12.5     19.9       0.0          8.4       5.3           43.0
# 364     12.5     26.9       0.0          5.0       7.1           46.0
# 365     12.3     30.2       0.0          6.0      12.6           78.0
#
#      WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# ...

# %% [markdown]
# get data comun from table

# %%
data = data[['MinTemp','MaxTemp','Rainfall']]
data
# Out:
#      MinTemp  MaxTemp  Rainfall
# 0        8.0     24.3       0.0
# 1       14.0     26.9       3.6
# 2       13.7     23.4       3.6
# 3       13.3     15.5      39.8
# 4        7.6     16.1       2.8
# ..       ...      ...       ...
# 361      9.0     30.7       0.0
# 362      7.1     28.4       0.0
# 363     12.5     19.9       0.0
# 364     12.5     26.9       0.0
# 365     12.3     30.2       0.0
#
# [366 rows x 3 columns]

# %% [markdown]
# Count in columns values

# %%
data.count()
# Out:
# MinTemp     366
# MaxTemp     366
# Rainfall    366
# dtype: int64

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall
# 0      8.0     24.3       0.0
# 1     14.0     26.9       3.6
# 2     13.7     23.4       3.6
# 3     13.3     15.5      39.8
# 4      7.6     16.1       2.8

# %%
data.head(20)
# Out:
#     MinTemp  MaxTemp  Rainfall
# 0       8.0     24.3       0.0
# 1      14.0     26.9       3.6
# 2      13.7     23.4       3.6
# 3      13.3     15.5      39.8
# 4       7.6     16.1       2.8
# 5       6.2     16.9       0.0
# 6       6.1     18.2       0.2
# 7       8.3     17.0       0.0
# 8       8.8     19.5       0.0
# 9       8.4     22.8      16.2
# 10      9.1     25.2       0.0
# 11      8.5     27.3       0.2
# 12     10.1     27.9       0.0
# 13     12.1     30.9       0.0
# 14     10.1     31.2       0.0
# 15     12.4     32.1       0.0
# 16     13.8     31.2       0.0
# 17     11.7     30.0       1.2
# 18     12.4     32.3       0.6
# 19     15.6     33.4       0.0

# %% [markdown]
# if column have missing values we can fill that with own column mean

# %%
data.MaxTemp = data.MaxTemp.fillna(data.MaxTemp.mean()) #filling the missing values with the mean of the column using fillna 
#(fillna finds missing values and fills them with the value we provide)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12752\2834604643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.MaxTemp = data.MaxTemp.fillna(data.MaxTemp.mean()) #filling the missing values with the mean of the column using fillna

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall
# 0        8.0     24.3       0.0
# 1       14.0     26.9       3.6
# 2       13.7     23.4       3.6
# 3       13.3     15.5      39.8
# 4        7.6     16.1       2.8
# ..       ...      ...       ...
# 361      9.0     30.7       0.0
# 362      7.1     28.4       0.0
# 363     12.5     19.9       0.0
# 364     12.5     26.9       0.0
# 365     12.3     30.2       0.0
#
# [366 rows x 3 columns]

# %% [markdown]
# Adding conditions

# %%
data['MaxTemp']>45
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Name: MaxTemp, Length: 366, dtype: bool

# %%
condition = data['MaxTemp']>35
filter = data[condition]
filter
# Out:
#      MinTemp  MaxTemp  Rainfall
# 71      17.5     35.8       0.0
# 72      20.9     35.7       0.0
# 135     13.8     35.2       0.0

# %%
filter['Rainfall']
# Out:
# 71     0.0
# 72     0.0
# 135    0.0
# Name: Rainfall, dtype: float64

# %% [markdown]
# Multiple conditions

# %%
condition = ( data['MaxTemp']>26 ) & ( data['Rainfall']>1)
filter = data[condition]
filter
# Out:
#      MinTemp  MaxTemp  Rainfall
# 1       14.0     26.9       3.6
# 17      11.7     30.0       1.2
# 31      11.6     26.3       4.2
# 33      13.3     26.5       6.6
# 37      16.5     28.2       4.0
# 50      14.8     29.5       6.4
# 57      15.1     28.3      14.4
# 73      17.0     33.8       2.0
# 91      17.6     27.8       5.2
# 113     12.7     28.6       6.6
# 128      9.5     27.4       3.0

# %%
filter['MinTemp']
# Out:
# 1      14.0
# 17     11.7
# 31     11.6
# 33     13.3
# 37     16.5
# 50     14.8
# 57     15.1
# 73     17.0
# 91     17.6
# 113    12.7
# 128     9.5
# Name: MinTemp, dtype: float64

# %% [markdown]
# dataset information

# %%
data.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall
# count  366.000000  366.000000  366.000000
# mean     7.265574   20.550273    1.428415
# std      6.025800    6.690516    4.225800
# min     -5.300000    7.600000    0.000000
# 25%      2.300000   15.025000    0.000000
# 50%      7.450000   19.650000    0.000000
# 75%     12.500000   25.500000    0.200000
# max     20.900000   35.800000   39.800000

# %% [markdown]
# dataset visualize

# %%
import matplotlib.pyplot as plt 
x = range(366)
y1 = data['MinTemp']
y2 = data['MaxTemp']
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
import matplotlib.pyplot as plt 
x = range(100)
y1 = data['MinTemp'][:100]
y2 = data['MaxTemp'][:100]
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()
